# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        """
        Appends a new node with the given data to the end of the doubly linked list.
        """
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current

    def prepend(self, data):
        """
        Prepends a new node with the given data at the beginning of the doubly linked list.
        """
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def delete(self, data):
        """
        Deletes a node with the given data from the doubly linked list.
        """
        current = self.head
        while current:
            if current.data == data:
                if current.prev:
                    current.prev.next = current.next
                else:
                    self.head = current.next
                if current.next:
                    current.next.prev = current.prev
                return
            current = current.next

    def print_forward(self):
        """
        Prints the elements of the doubly linked list in forward order.
        """
        current = self.head
        while current:
            print(current.data, end=" <-> ")
            current = current.next
        print("None")

#     def print_backward(self):
#         """
#         Prints the elements of the doubly linked list in reverse order.
#         """
#         current = self.head
#         while current and current.next:
#             current = current.next
#         while current:
#             print(current.data, end=" <-> ")
#             current = current.prev
#         print("None")

# Example usage:

dll = DoublyLinkedList()
dll.append(1)
dll.append(2)
dll.append(3)
dll.prepend(0)
dll.delete(2)

dll.print_forward()
#dll.print_backward()
# Out:
# 0 <-> 1 <-> 3 <-> None

# %%
def fact(n):
    if (n==0 or n==1):
        return 1
    else:
        val = n*fact(n-1)
        return val
result = fact(5)
print(result)
# Out:
# 120

# %%
def ftn():
    print('hello')
ftn()
# Out:
# hello

# %%
def ad(x,y):
    sum = x+y
    return sum
ad(2,3)
# Out:
# 5

# %%
def ftn(n):
    if n==1:
        return 1
    else:
        val= n+ftn(n-1)
        print('ali is my friend')
        return val


ft()
def ft():
    for i in range(4):
        print('love to see')
ftn(4)
# Out:
# love to see
# love to see
# love to see
# love to see
# ali is my friend
# ali is my friend
# ali is my friend
# 10

# %%
# here I am going to create tree
class Node:
    def __init__(self, value):
        self.left = None
        self.data = value
        self.right = None
        
class Tree:
    def createNode(self, data):
        return Node(data)
    def insert(self, node, data):
        if node is None:
            return self.createNode(data)
        if data < node.data:
            node.left = self.insert(node.left, data)
        else:
            node.right = self.insert(node.right, data)
        return node   
    
    def travers_Inorder(self, data):         #left root right
        if root is not None:
            self.travers_Inorder(root.left)
            print(root.data)
            self.travers_Inorder(root.right)
    def travers_Preorder(self, root):        # root left right
        if root is not None:
            print(root.data)
            self.travers_Inorder(root.left)
            self.travers_Inorder(root.right)
            
    def travers_Postorder(self, root):
         if root is not None:
            self.travers_Postorder(root.left)
            self.travers_Postorder(root.right)
            print(root.data)
            
            
    def hieght(self, root):
        if root is None:
            return -1
        return max(self.hieght(root.left),self.hieght(root.right)) +1
    # ...

    def delete(self, root, key):
        if root is None:
            return root

        # Recur down the tree
        if key < root.data:
            root.left = self.delete(root.left, key)
        elif key > root.data:
            root.right = self.delete(root.right, key)
        else:
            # Node with only one child or no child
            if root.left is None:
                temp = root.right
                root = None
                return temp
            elif root.right is None:
                temp = root.left
                root = None
                return temp

            # Node with two children: get the inorder successor
            temp = self.min_value_node(root.right)

            # Copy the inorder successor's content to this node
            root.data = temp.data

            # Delete the inorder successor
            root.right = self.delete(root.right, temp.data)

        return root

    def min_value_node(self, node):
        current = node
        while current.left is not None:
            current = current.left
        return current

# ...
 
#     def delete(self, root):
#         if root is not None:
#             self.delete(root.left)
#             self.delete(root.right)
#             #self.delete(root)
#             print('deleting node', root.data)
#             del root
data = [5, 2, 4, 10, 12, 7, 16, 3,19]            
tree = Tree()
root = tree.createNode(8)
root = None  # Initialize the root as None

# Insert data from the list into the tree
for value in data:
    root = tree.insert(root, value)
print(root.data)
#print(tree.insert)
print('Inorder-->')
#tree.travers_Inorder(root)
#print('Preorder -->')
#tree.travers_Preorder(root)
#print('travers_Postorder -------->')
#tree.travers_Postorder(root)
print('Hieght -------->')
#print(tree.hieght(root))
print('delete -------->')
# tree.delete(root)
# print(root.data)
# print('Preorder -->')
print(tree.travers_Postorder(root))
# To delete a specific node from the tree, call the delete method with the root and the key to be deleted.
key_to_delete = 10  # Change this to the key you want to delete
root = tree.delete(root, key_to_delete)
# print('Preorder -->')
# tree.travers_Preorder(root)
print(tree.travers_Postorder(root))
# Out:
# 5
# Inorder-->
# Hieght -------->
# delete -------->
# 3
# 4
# 2
# 7
# 19
# 16
# 12
# 10
# 5
# None
# 3
# 4
# 2
# 7
# 19
# 16
# 12
# 5
# None

# %%
class Node:
    def __init__(self, value):
        self.left = None
        self.data = value
        self.right = None

class Tree:
    def createNode(self, data):
        return Node(data)

    def insert(self, root, data):
        if root is None:
            return self.createNode(data)
        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)
        return root

    def traverse_inorder(self, node):
        if node:
            self.traverse_inorder(node.left)
            print(node.data)
            self.traverse_inorder(node.right)

    def traverse_preorder(self, node):
        if node:
            print(node.data)
            self.traverse_preorder(node.left)
            self.traverse_preorder(node.right)

    def traverse_postorder(self, node):
        if node:
            self.traverse_postorder(node.left)
            self.traverse_postorder(node.right)
            print(node.data)

    def delete(self, root, key):
        if root is None:
            return root
        if key < root.data:
            root.left = self.delete(root.left, key)
        elif key > root.data:
            root.right = self.delete(root.right, key)
        else:
            if root.left is None:
                temp = root.right
                root = None
                return temp
            elif root.right is None:
                temp = root.left
                root = None
                return temp
            temp = self.min_value_node(root.right)
            root.data = temp.data
            root.right = self.delete(root.right, temp.data)
        return root

    def height(self, root):
        if root is None:
            return 0
        return max(self.height(root.left), self.height(root.right)) + 1

    def min_value_node(self, node):
        current = node
        while current.left is not None:
            current = current.left
        return current

data = [5, 2, 4, 10, 12, 7, 16, 3, 19]
tree = Tree()
root = tree.createNode(8)
root = None  # Initialize the root as None

# Insert data from the list into the tree
for value in data:
    root = tree.insert(root, value)

print('Inorder -->')
tree.traverse_inorder(root)

print('Preorder -->')
tree.traverse_preorder(root)

print('Postorder -->')
tree.traverse_postorder(root)

print('Height -->')
print(tree.height(root))

# To delete a specific node from the tree, call the delete method with the root and the key to be deleted.
key_to_delete = 10  # Change this to the key you want to delete
root = tree.delete(root, key_to_delete)

print('Inorder after deleting key 10 -->')
tree.traverse_inorder(root)
# Out:
# Inorder -->
# 2
# 3
# 4
# 5
# 7
# 10
# 12
# 16
# 19
# Preorder -->
# 5
# 2
# 4
# 3
# 10
# 7
# 12
# 16
# 19
# Postorder -->
# 3
# 4
# 2
# 7
# 19
# 16
# 12
# 10
# 5
# Height -->
# 5
# Inorder after deleting key 10 -->
# 2
# 3
# 4
# 5
# 7
# 12
# 16
# 19
